# %%
#!apt update
#!apt install chromium-chromedriver
! pip install selenium

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait

import pandas as pd
# Out:
# Requirement already satisfied: selenium in c:\users\bened\anaconda3\envs\webanalytics\lib\site-packages (4.15.2)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\bened\anaconda3\envs\webanalytics\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.1.0)
# Requirement already satisfied: trio~=0.17 in c:\users\bened\anaconda3\envs\webanalytics\lib\site-packages (from selenium) (0.23.1)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\bened\anaconda3\envs\webanalytics\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\bened\anaconda3\envs\webanalytics\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\bened\anaconda3\envs\webanalytics\lib\site-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\bened\anaconda3\envs\webanalytics\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\bened\anaconda3\envs\webanalytics\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\bened\anaconda3\envs\webanalytics\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\bened\anaconda3\envs\webanalytics\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\bened\anaconda3\envs\webanalytics\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\bened\anaconda3\envs\webanalytics\lib\site-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: wsproto>=0.14 in c:\users\bened\anaconda3\envs\webanalytics\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\bened\anaconda3\envs\webanalytics\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\bened\anaconda3\envs\webanalytics\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\bened\anaconda3\envs\webanalytics\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
def extract_value_from_format(input):
    value = None    # TODO: maybe use NaN instead!?

    input = input.replace(",","") # erase every ",", they just show the thousends: 1,234. To spilt decimals, the "." is used
    if "%" in input:
        value = float(input.replace("%", ""))
    elif "M" in input:
        value = float(input.replace("M", "")) * 1000 * 1000
    elif "B" in input:
        value = float(input.replace("B", "")) * 1000 * 1000 * 1000
    elif input.replace('.','',1).isdigit():
        value = float(input)
    elif "N/A" in input:
        pass  # value = None
    else:
        print("input not preprocessed: ", input)

    return value

# %%
def get_key_from_metric_label(label):
    return label.replace(" ", "_")

def add_metrics_from_site(driver, metrics, metrics_by_label):
    
    if len(driver.find_elements(By.ID, 'Col1-0-KeyStatistics-Proxy')) == 0:
        print("ERROR: no key-statistics page found! Returns empty metrics")
        return metrics + [None] * (len(metrics_by_label) - 1) # return placeholders
    
    
    metrics_body = driver.find_element(By.ID, 'Col1-0-KeyStatistics-Proxy')
    
    for metric_label in metrics_by_label:
        if metric_label == Metrics.TICKER: # tickername only for dataframe-label reasons. Maybe change logic to more sothisticated list 
            continue
            
        market_cap_element = metrics_body.find_element(By.XPATH, "//tr[contains(., '"+metric_label+"')]")
        child_elements = market_cap_element.find_elements(By.XPATH, "./*")

        assert(len(child_elements) == 2)
        
        # extract values from format
        value = extract_value_from_format(child_elements[1].text) 
        metrics.append(value)
        
        # TODO!
        #if get_key_from_metric_label(child_elements[0].text) != metric_label:
        #    print("Caution: modified metric-name from website " + get_key_from_metric_label(child_elements[0].text) + " differs from the used column-key: "+ metric_label )
        
        
        #metrics[get_key_from_metric_label(child_elements[0].text)] = child_elements[1].text
        #metrics.append((child_elements[0].text, child_elements[1].text))  # TODO return metric_label value (but be aware of the contains-search!)

    return metrics

# %%
# supporting class with constants from the website (keys etc.)
class Metrics(object):
    
    # Valuation Measures
    MARKET_CAP = 'Market Cap'
    MARKET_CAP_KEY = 'Market_Cap'
    ENTERPRISE_VALUE = 'Enterprise Value'
    ENTERPRISE_VALUE_KEY = 'Enterprise_Value'
    
    
    # Profitability
    PM = "Profit Margin"
    OM = "Operating Margin"
    
    # Management Effectiveness
    ROA = "Return on Assets"
    ROE = "Return on Equity"
    
    # Balance Sheet
    TC = "Total Cash (mrq)"  # CAUTION! search only by contains, not equals!
    TCPS = "Total Cash Per Share (mrq)"
    TD = "Total Debt (mrq)"  # CAUTION! search only by contains, not equals!
    TDE = "Total Debt/Equity (mrq)"
    # ...
    
    # Cash Flow Statement
    OCF = "Operating Cash Flow"
    LFCF = "Levered Free Cash Flow"
    
    # Dividiens & Splits
    FADR = "Forward Annual Dividend Rate"
    FADY = "Forward Annual Dividend Yield"
    TADR = "Trailing Annual Dividend Rate"
    TADY = "Trailing Annual Dividend Yield"
    Y5ADY = "5 Year Average Dividend Yield"
    PR = "Payout Ratio"
    # ...
    
    base = []
    TICKER = "Ticker"
    
    
    def __init__(self):
        self.base = [self.TICKER]
    
    def basics(self, addBase=False):
        if addBase:
            return self.base + [self.MARKET_CAP, self.ENTERPRISE_VALUE]
        else:
            return [self.MARKET_CAP, self.ENTERPRISE_VALUE]
    
    def diviends(self, addBase=False):
        if addBase:
            return self.base + [self.FADR, self.FADY, self.TADR, self.TADY, self.Y5ADY, self.PR]
        else:
            return [self.FADR, self.FADY, self.TADR, self.TADY, self.Y5ADY, self.PR]
        
    
    def dividends_slides(self, addBase=False):
        if addBase:
            return self.base + [self.FADY, self.TADY, self.Y5ADY, self.PR, self.PM, self.ROE, self.TC]
        else:
            return [self.FADY, self.TADY, self.Y5ADY, self.PR, self.PM, self.ROE, self.TC]
    
    def stability_slides(self, addBase=False):
        if addBase:
            return self.base + [self.TDE, self.OCF, self.LFCF]
        else:
            return [self.TDE, self.OCF, self.LFCF]
    
    def from_slides(self):
        return self.dividends_slides(addBase=True) + self.stability_slides()
    
    

class Tickerinfo(object):  # for additional type security
    
    def __init__(self, name, url):
        self.name = name
        self.url = url

# %%
import time 

def get_nasdaq_100_tickers():
    # get nasdaq-100 tickers from
    # https://www.nasdaq.com/market-activity/quotes/nasdaq-ndx-index

    print("set up driver for nasdaq website")
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC

    options = webdriver.ChromeOptions()
    #options.add_argument('--headless') # for not displaying the graphical environment, shows virtualized browser without GUI
    options.add_argument('--no-sandbox') # so that it can access machine resources, blocking sandbox processes it can access whatever
    options.add_argument('--disable-dev-shm-usage')  # colab does not have enough memory
    # open it, go to a website, and get results
    driver = webdriver.Chrome(options=options)


    try:
        url = "https://www.nasdaq.com/market-activity/quotes/nasdaq-ndx-index"
        driver.get(url)

        time.sleep(5)
        # Accept cookies by clicking the button with the specified ID
        #iframe = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.ID, 'onetrust-banner-sdk')))

        print("accept cookies")
        #print(driver.page_source)
        iframe = driver.find_element(By.ID, 'onetrust-banner-sdk')
        accept_cookies_button = iframe.find_element(By.ID, 'onetrust-accept-btn-handler')
        accept_cookies_button.click()


        print("get nasdaq-100 tickers")

        # call url with tickers:

        tab = driver.find_element(By.TAG_NAME, 'tbody')
        tickers = []
        assert(tab)
        elements = tab.find_elements(By.TAG_NAME, 'tr')

        print("amount of tickers: ", len(elements))
        #elements = elements[:5]  # TODO, take all tickers (only for testing)


        links = [e.find_element(By.TAG_NAME, 'a') for e in elements]

        for l in links:
            tickers.append(Tickerinfo(l.text, l.get_attribute("href")))

        print("getting tickers finished")
    finally:
        # Close the WebDriver
        driver.quit()

    print()
    print("finished scraping nasdaq website")
    
    return tickers

# %%
def get_trending_tickers_yahoo(driver):
    print("call trending tickers")
    # call url with tickers:
    driver.get("https://finance.yahoo.com/trending-tickers")
    
    tab = driver.find_element(By.TAG_NAME, 'tbody')
    tickers = []
    assert(tab)
    elements = tab.find_elements(By.TAG_NAME, 'tr')
    
    print("amount of tickers: ", len(elements))
    #elements = elements[:5]  # TODO, take all tickers (only for testing)
    
    
    links = [e.find_element(By.TAG_NAME, 'a') for e in elements]

    for l in links:
        tickers.append(Tickerinfo(l.text, l.get_attribute("href")))
    
    print("getting tickers finished")
    return tickers

# %%
print("set up driver for yahoo finance website")

options = webdriver.ChromeOptions()
options.add_argument('--headless') # for not displaying the graphical environment, shows virtualized browser without GUI
options.add_argument('--no-sandbox') # so that it can access machine resources, blocking sandbox processes it can access whatever
options.add_argument('--disable-dev-shm-usage')  # colab does not have enough memory
# open it, go to a website, and get results
driver = webdriver.Chrome(options=options)

url = "https://finance.yahoo.com/"
driver.get(url)

try:
    # Accept cookies by clicking the button with the specified ID
    print("accept cookies")
    iframe = driver.find_element(By.CLASS_NAME, 'con-wizard')
    accept_cookies_button = iframe.find_element(By.CLASS_NAME, 'accept-all')
    accept_cookies_button.click()
    
    #tickers = get_trending_tickers_yahoo(driver)
    tickers = get_nasdaq_100_tickers()
    
    print("get metrics for "+str(len(tickers))+" tickers")
    required_metrics = Metrics().from_slides()
    
    df_metrics = pd.DataFrame(columns=[get_key_from_metric_label(label) for label in required_metrics])
    
    # call metric-webpage for each ticker and scrape values
    for ticker in tickers:
        #if not ticker.name == "ES=F":
        #    continue
            
        tickername = ticker.name
        print()
        print("ticker: ", tickername)
        url = "https://finance.yahoo.com/quote/"+tickername+"/key-statistics?p="+tickername
        driver.get(url)

        metrics = [tickername]
         # get metric values from website
        print("start scraping metrics for ticker from: ", driver.current_url)
        metrics = add_metrics_from_site(driver, metrics, required_metrics)

         # add metrics as new last row to df
        df_metrics.loc[len(df_metrics)] = metrics

    #print(df_metrics)

finally:
    # Close the WebDriver
    driver.quit()
    
print()
print("finished scraping")
# Out:
# set up driver for yahoo finance website
# accept cookies
# set up driver for nasdaq website
# accept cookies
# get nasdaq-100 tickers
# amount of tickers:  78
# getting tickers finished
#
# finished scraping nasdaq website
# get metrics for 78 tickers
#
# ticker:  AAPL
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/AAPL/key-statistics?p=AAPL
#
# ticker:  ABNB
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/ABNB/key-statistics?p=ABNB
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  ADBE
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/ADBE/key-statistics?p=ADBE
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  ADI
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/ADI/key-statistics?p=ADI
#
# ticker:  ADP
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/ADP/key-statistics?p=ADP
#
# ticker:  AEP
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/AEP/key-statistics?p=AEP
#
# ticker:  ALGN
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/ALGN/key-statistics?p=ALGN
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  AMGN
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/AMGN/key-statistics?p=AMGN
#
# ticker:  ANSS
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/ANSS/key-statistics?p=ANSS
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  ASML
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/ASML/key-statistics?p=ASML
#
# ticker:  AVGO
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/AVGO/key-statistics?p=AVGO
#
# ticker:  AZN
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/AZN/key-statistics?p=AZN
#
# ticker:  BIIB
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/BIIB/key-statistics?p=BIIB
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  BKNG
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/BKNG/key-statistics?p=BKNG
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  BKR
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/BKR/key-statistics?p=BKR
#
# ticker:  CDNS
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/CDNS/key-statistics?p=CDNS
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  CEG
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/CEG/key-statistics?p=CEG
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  CHTR
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/CHTR/key-statistics?p=CHTR
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  CMCSA
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/CMCSA/key-statistics?p=CMCSA
#
# ticker:  COST
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/COST/key-statistics?p=COST
#
# ticker:  CPRT
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/CPRT/key-statistics?p=CPRT
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  CRWD
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/CRWD/key-statistics?p=CRWD
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  CSCO
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/CSCO/key-statistics?p=CSCO
#
# ticker:  CSGP
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/CSGP/key-statistics?p=CSGP
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  CSX
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/CSX/key-statistics?p=CSX
#
# ticker:  CTAS
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/CTAS/key-statistics?p=CTAS
#
# ticker:  CTSH
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/CTSH/key-statistics?p=CTSH
#
# ticker:  DDOG
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/DDOG/key-statistics?p=DDOG
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  DLTR
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/DLTR/key-statistics?p=DLTR
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  EA
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/EA/key-statistics?p=EA
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  EXC
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/EXC/key-statistics?p=EXC
#
# ticker:  FAST
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/FAST/key-statistics?p=FAST
#
# ticker:  GEHC
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/GEHC/key-statistics?p=GEHC
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  GFS
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/GFS/key-statistics?p=GFS
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  GILD
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/GILD/key-statistics?p=GILD
#
# ticker:  GOOGL
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/GOOGL/key-statistics?p=GOOGL
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  IDXX
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/IDXX/key-statistics?p=IDXX
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  ILMN
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/ILMN/key-statistics?p=ILMN
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  INTU
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/INTU/key-statistics?p=INTU
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  ISRG
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/ISRG/key-statistics?p=ISRG
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  KDP
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/KDP/key-statistics?p=KDP
#
# ticker:  KHC
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/KHC/key-statistics?p=KHC
#
# ticker:  KLAC
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/KLAC/key-statistics?p=KLAC
#
# ticker:  LCID
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/LCID/key-statistics?p=LCID
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  LRCX
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/LRCX/key-statistics?p=LRCX
#
# ticker:  LULU
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/LULU/key-statistics?p=LULU
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  MAR
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/MAR/key-statistics?p=MAR
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  MCHP
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/MCHP/key-statistics?p=MCHP
#
# ticker:  MDLZ
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/MDLZ/key-statistics?p=MDLZ
#
# ticker:  MELI
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/MELI/key-statistics?p=MELI
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  META
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/META/key-statistics?p=META
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  MNST
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/MNST/key-statistics?p=MNST
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  MRVL
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/MRVL/key-statistics?p=MRVL
#
# ticker:  NFLX
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/NFLX/key-statistics?p=NFLX
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  NXPI
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/NXPI/key-statistics?p=NXPI
#
# ticker:  ODFL
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/ODFL/key-statistics?p=ODFL
#
# ticker:  ON
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/ON/key-statistics?p=ON
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  ORLY
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/ORLY/key-statistics?p=ORLY
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  PANW
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/PANW/key-statistics?p=PANW
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  PAYX
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/PAYX/key-statistics?p=PAYX
#
# ticker:  PCAR
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/PCAR/key-statistics?p=PCAR
#
# ticker:  PDD
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/PDD/key-statistics?p=PDD
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  PEP
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/PEP/key-statistics?p=PEP
#
# ticker:  REGN
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/REGN/key-statistics?p=REGN
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  SBUX
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/SBUX/key-statistics?p=SBUX
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  SGEN
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/SGEN/key-statistics?p=SGEN
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  SIRI
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/SIRI/key-statistics?p=SIRI
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  SNPS
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/SNPS/key-statistics?p=SNPS
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  TEAM
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/TEAM/key-statistics?p=TEAM
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  TMUS
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/TMUS/key-statistics?p=TMUS
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  TTD
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/TTD/key-statistics?p=TTD
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  VRSK
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/VRSK/key-statistics?p=VRSK
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  VRTX
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/VRTX/key-statistics?p=VRTX
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  WBD
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/WBD/key-statistics?p=WBD
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  WDAY
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/WDAY/key-statistics?p=WDAY
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  XEL
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/XEL/key-statistics?p=XEL
#
# ticker:  ZM
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/ZM/key-statistics?p=ZM
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# ticker:  ZS
# start scraping metrics for ticker from:  https://finance.yahoo.com/quote/ZS/key-statistics?p=ZS
# C:\Users\bened\AppData\Local\Temp\ipykernel_31836\2782785839.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_metrics.loc[len(df_metrics)] = metrics
# finished scraping

# %%
df_metrics
# Out:
#    Ticker  Forward_Annual_Dividend_Yield  Trailing_Annual_Dividend_Yield  \
# 0    AAPL                           0.51                            0.49
# 1    ABNB                            NaN                            0.00
# 2    ADBE                            NaN                            0.00
# 3     ADI                           1.88                            1.88
# 4     ADP                           2.44                            2.17
# ..    ...                            ...                             ...
# 73    WBD                            NaN                            0.00
# 74   WDAY                            NaN                            0.00
# 75    XEL                           3.42                            3.37
# 76     ZM                            NaN                            0.00
# 77     ZS                            NaN                            0.00
#
#     5_Year_Average_Dividend_Yield  Payout_Ratio  Profit_Margin  \
# 0                            0.82         15.33          25.31
# 1                             NaN          0.00          56.87
# 2                            0.12          0.00          27.11
# 3                            1.83         50.99          26.94
# 4                            1.98         59.38          19.08
# ..                            ...           ...            ...
# 73                            NaN          0.00         -11.48
# 74                            NaN          0.00           0.96
# 75                           2.74         64.79          11.75
# 76                            NaN          0.00           5.21
# 77                            NaN          0.00          -9.54
#
#     Return_on_Equity  Total_Cash_(mrq)  Total_Debt/Equity_(mrq)  \
# 0             171.95      6.155000e+10                   199.42
# 1              74.47      1.096000e+10                    25.31
# 2              33.97      7.520000e+09                    25.96
# 3               9.20      9.580600e+08                    20.96
# 4             115.46      1.460000e+09                   108.45
# ..               ...               ...                      ...
# 73             -9.91      2.470000e+09                    97.11
# 74              1.11      6.880000e+09                    49.45
# 75             10.33      6.350000e+08                   157.06
# 76              3.56      6.490000e+09                     1.07
# 77            -27.07      2.320000e+09                   150.55
#
#     Operating_Cash_Flow  Levered_Free_Cash_Flow
# 0          1.105400e+11            8.218000e+10
# 1          4.280000e+09            2.880000e+09
# 2          8.030000e+09            7.320000e+09
# 3          4.820000e+09            3.310000e+09
# 4          3.820000e+09            3.540000e+09
# ..                  ...                     ...
# 73         6.740000e+09            2.150000e+10
# 74         1.850000e+09            1.700000e+09
# 75         5.120000e+09           -1.030000e+09
# 76         1.460000e+09            1.620000e+09
# 77         5.946900e+08            5.782700e+08
#
# [78 rows x 11 columns]

# %%
import os

base = '/'.join(os.getcwd().split('/')[:-1])
datasetpath = os.path.join(base, 'Dataset')
df_metrics.to_csv(os.path.join(datasetpath, 'data.csv'))
# Out:
# '/home/jorge/Desktop/Data science/4/WA/Final/StockAnalysis-tool/Dataset'

# %%
# get nasdaq-100 tickers from
# https://www.nasdaq.com/market-activity/quotes/nasdaq-ndx-index

from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

options = webdriver.ChromeOptions()
#options.add_argument('--headless') # for not displaying the graphical environment, shows virtualized browser without GUI
options.add_argument('--no-sandbox') # so that it can access machine resources, blocking sandbox processes it can access whatever
options.add_argument('--disable-dev-shm-usage')  # colab does not have enough memory
# open it, go to a website, and get results
driver = webdriver.Chrome(options=options)


try:
    url = "https://www.nasdaq.com/market-activity/quotes/nasdaq-ndx-index"
    driver.get(url)
    
    # Accept cookies by clicking the button with the specified ID
    iframe = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.ID, 'onetrust-banner-sdk')))
    
    print("accept cookies")
    iframe = driver.find_element(By.ID, 'onetrust-banner-sdk')
    accept_cookies_button = iframe.find_element(By.ID, 'onetrust-accept-btn-handler')
    accept_cookies_button.click()
    
    
    print("call nasdaq-100 tickers")

    

    # call url with tickers:
    
    tab = driver.find_element(By.TAG_NAME, 'tbody')
    tickers = []
    assert(tab)
    elements = tab.find_elements(By.TAG_NAME, 'tr')
    
    print("amount of tickers: ", len(elements))
    #elements = elements[:5]  # TODO, take all tickers (only for testing)
    
    
    links = [e.find_element(By.TAG_NAME, 'a') for e in elements]

    for l in links:
        tickers.append(Tickerinfo(l.text, l.get_attribute("href")))
    
    print("getting tickers finished")
finally:
    # Close the WebDriver
    driver.quit()
    
print()
print("finished scraping")
# Out:
# accept cookies
# <html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# " class=" js"><head>
#   <meta charset="utf-8">
# <script async="" type="text/javascript" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js" data-ad-client="ca-pub-1861191755926748"></script><script id="#livevalidationscript" src="https://img04.en25.com/i/livevalidation_standalone.compressed.js"></script><script src="https://www.googletagmanager.com/gtm.js?id=GTM-TB9QCTB&amp;gtm_auth=AbgJsDZWx9ClJu0CVnQWXA&amp;gtm_preview=env-10&amp;gtm_cookies_win=x" async=""></script><script async="" src="//c.amazon-adsystem.com/aax2/apstag.js"></script><script async="" type="text/javascript" src="https://ad.wsod.com/site/2caa62b3a3a0755e2cda9deea9070934/0.0.async/"></script><script>window.digitalData = {"pageInstanceID":"production:home:market-activity:quotes:nasdaq-ndx-index","page":{"pageInfo":{"author":null,"breadcrumbs":["home","market-activity","quotes","nasdaq-ndx-index"],"destinationURL":"https:\/\/www.nasdaq.com\/market-activity\/quotes\/nasdaq-ndx-index","entryURL":null,"lang":"en","onsiteSearchResults":null,"onsiteSearchTerm":null,"pageID":"home:market-activity:quotes:nasdaq-ndx-index","pageName":"nasdaq-ndx-index","pagePathLevel1":"market-activity","pagePathLevel2":"market-activity:quotes","pagePathLevel3":"market-activity:quotes:nasdaq-ndx-index","pagePathLevel4":null,"pagePathLevel5":null,"publisher":null,"articleTitle":null,"publisherTimestamp":null,"referringURL":null,"sysEnv":null,"timeStamp":1701446468,"refreshDisable":false,"disableVideoAds":false,"customPageName":"market-activity__index","sponsoredContent":false,"nativeRefreshDisable":[],"platform":"rrp"},"category":{"eventType":null,"pageType":"market-activity-landing-page","videoType":null,"storyType":null,"primaryCategory":"market-activity","subCategory":null},"attributes":{"adDisplay":false,"assetClass":null,"businessUnit":null,"campaignParameters":null,"industry":null,"quoteSymbol":null,"region":null,"sponsored":false,"topic":null,"audience":null,"glossaryTerm":null},"additionalAttributes":{"pageType":"market-activity-landing-page","quoteSymbolList":null,"assetClass":null,"primaryTopic":null,"additionalTopics":null,"topicsList":[]}},"user":[{"segment":{"loginStatus":"guest","registrationStatus":"anonymous","cookieOptIn":true,"termsOptIn":false,"offersOptIn":false}}]};</script>
# <script src="https://www.nasdaq.com/sites/acquia.prod/files/google_tag/nasdaq_gtm/google_tag.script.js?s4t9uh" defer=""></script>
# <meta name="title" content="Quotes For Nasdaq-100 Index | Nasdaq">
# <meta name="description" content="Free Stock Quotes Nasdaq Amex NYSE, Options and Mutual Funds, Investment information, Portfolio Tracking, Ticker">
# <link rel="canonical" href="https://www.nasdaq.com/market-activity/quotes/nasdaq-ndx-index">
# <meta property="og:type" content="Market Activity Landing">
# <meta property="og:url" content="https://www.nasdaq.com/market-activity/quotes/nasdaq-ndx-index">
# <meta property="og:title" content="Quotes For Nasdaq-100 Index">
# <meta property="og:image" content="https://www.nasdaq.com/sites/acquia.prod/files/2019-03/Index-Data.png?1829646644">
# <meta property="og:image:width" content="1200">
# <meta property="og:image:height" content="630">
# <meta name="twitter:card" content="summary_large_image">
# <meta name="twitter:site" content="@Nasdaq">
# <meta name="twitter:title" content="Quotes For Nasdaq-100 Index">
# <meta name="twitter:site:id" content="nasdaq">
# <meta name="twitter:url" content="https://www.nasdaq.com/market-activity/quotes/nasdaq-ndx-index">
# <link rel="alternate" hreflang="en" href="https://www.nasdaq.com/market-activity/quotes/nasdaq-ndx-index">
# <meta name="com.nasdaq.cms.taxonomy.pageType" content="market-activity-landing-page">
# <meta name="Generator" content="Drupal 9 (https://www.drupal.org)">
# <meta name="MobileOptimized" content="width">
# <meta name="HandheldFriendly" content="true">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <meta name="storyType" content="">
# <script type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@graph": [
#         {
#             "@type": "Corporation",
#             "@id": "https://www.nasdaq.com/",
#             "name": "Nasdaq",
#             "url": "https://www.nasdaq.com/",
#             "logo": {
#                 "@type": "ImageObject",
#                 "url": "https://www.nasdaq.com/themes/nsdq/dist/assets/images/logo-half-white.svg"
#             }
#         },
#         {
#             "@type": "WebPage",
#             "breadcrumb": {
#                 "@type": "BreadcrumbList",
#                 "itemListElement": [
#                     {
#                         "@type": "ListItem",
#                         "position": 1,
#                         "name": "Home",
#                         "item": "https://www.nasdaq.com/"
#                     },
#                     {
#                         "@type": "ListItem",
#                         "position": 2,
#                         "name": "Market Activity",
#                         "item": "https://www.nasdaq.com/market-activity"
#                     },
#                     {
#                         "@type": "ListItem",
#                         "position": 3,
#                         "item": {
#                             "@id": "https://www.nasdaq.com/market-activity/quotes/nasdaq-ndx-index",
#                             "name": "Quotes For Nasdaq-100 Index",
#                             "url": "https://www.nasdaq.com/market-activity/quotes/nasdaq-ndx-index"
#                         }
#                     }
#                 ]
#             }
#         },
#         {
#             "@type": "WebSite",
#             "name": "Nasdaq",
#             "url": "https://www.nasdaq.com/",
#             "potentialAction": {
#                 "@type": "SearchAction",
#                 "target": "https://www.nasdaq.com/search?q={search_term_string}",
#                 "query-input": "required name=search_term_string"
#             }
#         }
#     ]
# }</script>
#
# <!-- Load the Prebid Magnite JavaScript Library -->
# <script async="" src="//securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script async="" src="//micro.rubiconproject.com/prebid/dynamic/22692.js?Nasdaq_Page_Template=market-activity-landing-page&amp;Nasdaq_Page_Name=nasdaq-ndx-index"></script>
#
# <script type="text/javascript">
# (function () {
#  function loadScript(tagSrc,client) {
#  var scriptTag = document.createElement('script'),
#  placeTag = document.getElementsByTagName("script")[0];
#  scriptTag.async = true;
#  scriptTag.type = "text/javascript";
#  scriptTag.src = tagSrc;
#  if (client !== null) {
#  scriptTag.setAttribute('data-ad-client', client);
#  }
#  placeTag.parentNode.insertBefore(scriptTag, placeTag);
#  }
#  var smartSrc = "https://ad.wsod.com/site/2caa62b3a3a0755e2cda9deea9070934/0.0.async/";
#  var autoSrc = "https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js";
#  var client = "ca-pub-1861191755926748";
# // Load the Smart Targets script
# loadScript(smartSrc,null);
#  if (window.digitalData.page.category.pageType != 'article-page') {
#    setTimeout(function () {
#       if (typeof drupalSettings != "undefined") {
#          const nplus = drupalSettings.user_info.user_nasdaq_plus;
#          if (!nplus) {
#             // Load Google Auto Ads script
#             loadScript(autoSrc,client);
#          }
#       }
#    }, 2000);
#  }
#  })();
#  </script>
#
# <script type="text/javascript">
# // Initialize the prebid variables.
#
# // Initialize the google variables.
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# // Add a place to store the slot name variable.
# googletag.slots = googletag.slots || {};
# // Add a place to store slots that are queued/observed
# // These are slots that we already stored but waiting to be fetched
# googletag.slotsQueued = googletag.slotsQueued || {};
#
# window.adsList = window.adsList || [];
# </script>
#
# <script type="text/javascript">
# //Load the APS JavaScript Library
# !function(a9,a,p,s,t,A,g){
#    if(a[a9])return;
#    function q(c,r){a[a9]._Q.push([c,r])}
#    a[a9]={
#       init:function(){q("i",arguments)},
#       fetchBids:function(){q("f",arguments)},
#       setDisplayBids:function(){},
#       targetingKeys:function(){return[]},_Q:[]
#    };
#       A=p.createElement(s);
#       A.async=!0;
#       A.src=t;
#       g=p.getElementsByTagName(s)[0];
#       g.parentNode.insertBefore(A,g)
#    }("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");
#
# //Initialize the Library
# apstag.init({
#     pubID: '3444',
#     adServer: 'googletag',
#     bidTimeout: 800,
#     deals: true
# });
# </script>
#
# <!-- Blockthrough Script -->
# <script src="https://btloader.com/tag?o=6304795636269056&amp;upapi=true" async=""></script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-EZY",
#     name: "/3244/market-activity__index/ATF_Leaderboard_QSD",
#     size: [[320, 50], [728, 90], [970, 250]] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [320, 50])
#                   .addSize([768, 0], [728, 90])
#                   .addSize([1024, 0], [728, 90])
#                   .addSize([1920, 0], [[728, 90], [970, 250]])
#                 .build();
#
#     googletag.slots["js-dfp-tag-EZY"] = googletag.defineSlot("/3244/market-activity__index/ATF_Leaderboard_QSD", [[320, 50], [728, 90], [970, 250]], "js-dfp-tag-EZY")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-abA",
#     name: "/3244/market-activity__index/ATF_RightRailBox",
#     size: [[300, 250], [300, 600]] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1024, 0], [[300, 250], [300, 600]])
#                   .addSize([0, 0], [])
#                 .build();
#
#     googletag.slots["js-dfp-tag-abA"] = googletag.defineSlot("/3244/market-activity__index/ATF_RightRailBox", [[300, 250], [300, 600]], "js-dfp-tag-abA")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-AJ8",
#     name: "/3244/market-activity__index/ATF_FindASymbolRight_1",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-AJ8"] = googletag.defineSlot("/3244/market-activity__index/ATF_FindASymbolRight_1", [120, 60], "js-dfp-tag-AJ8")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-f2Y",
#     name: "/3244/market-activity__index/ATF_FindASymbolLeft_2",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-f2Y"] = googletag.defineSlot("/3244/market-activity__index/ATF_FindASymbolLeft_2", [120, 60], "js-dfp-tag-f2Y")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-A3E",
#     name: "/3244/market-activity__index/ATF_FindASymbolRight_2",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-A3E"] = googletag.defineSlot("/3244/market-activity__index/ATF_FindASymbolRight_2", [120, 60], "js-dfp-tag-A3E")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-MNk",
#     name: "/3244/market-activity__index/ATF_FindASymbolLeft_1",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-MNk"] = googletag.defineSlot("/3244/market-activity__index/ATF_FindASymbolLeft_1", [120, 60], "js-dfp-tag-MNk")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-GEk",
#     name: "/3244/market-activity__index/ATF_RightRail2UpButton_1",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-GEk"] = googletag.defineSlot("/3244/market-activity__index/ATF_RightRail2UpButton_1", [120, 60], "js-dfp-tag-GEk")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-Tzg",
#     name: "/3244/market-activity__index/ATF_RightRail2UpButton_2",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-Tzg"] = googletag.defineSlot("/3244/market-activity__index/ATF_RightRail2UpButton_2", [120, 60], "js-dfp-tag-Tzg")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-gFc",
#     name: "/3244/market-activity__index/ATF_Native",
#     size: ["fluid"] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-gFc"] = googletag.defineSlot("/3244/market-activity__index/ATF_Native", ["fluid"], "js-dfp-tag-gFc")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-JUY",
#     name: "/3244/Watchlist/MyQuotesButton",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([768, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-JUY"] = googletag.defineSlot("/3244/Watchlist/MyQuotesButton", [120, 60], "js-dfp-tag-JUY")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-WD0",
#     name: "/3244/Watchlist/WatchlistButton_1",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([768, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-WD0"] = googletag.defineSlot("/3244/Watchlist/WatchlistButton_1", [120, 60], "js-dfp-tag-WD0")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# window.adsList.push({
#     id: "js-dfp-tag-lc4",
#     name: "/3244/Watchlist/MyQuotesButton2",
#     size: [120, 60] // Handle fluid size
# });
#
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([768, 0], [120, 60])
#                 .build();
#
#     googletag.slots["js-dfp-tag-lc4"] = googletag.defineSlot("/3244/Watchlist/MyQuotesButton2", [120, 60], "js-dfp-tag-lc4")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# googletag.cmd.push(function() {
#       googletag.pubads().enableAsyncRendering();
#         googletag.pubads().enableSingleRequest();
#           googletag.pubads().disableInitialLoad();
#       //Pulling the ad sizes from URL for testing the ad sizes
#   function test_check(){
#     if (window.location.href.indexOf("test") >= 0) {
#       var vars = window.location.href.split('?');
#       for (i in vars){
#         if (vars[i].indexOf("test") >= 0){
#           return [vars[i].split('=')[1]]
#         }
#       }}
#     return [""]
#   }
#   // GET Cookie code for making ad targeting easier
#   var reRegExpChar = /[\\^$.*+?()[\]{}|]/g,
#   reHasRegExpChar = RegExp(reRegExpChar.source);
#   function escapeRegExp(string) {
#     return string && reHasRegExpChar.test(string) ? string.replace(reRegExpChar, '\\$&') : string;
#   }
#   function getCookie(name) {
#     var k = escapeRegExp(name);
#     var v = document.cookie.match('(^|;) ?' + k + '=([^;]*)(;|$)');
#     return v ? v[2] : null;
#   }
#   function setCookie(name, value, days) {
#     const d = new Date();
#     d.setTime(d.getTime() + 24 * 60 * 60 * 1000 * days);
#     // eslint-disable-next-line prefer-template
#     document.cookie = name + '=' + value + ';path=/;expires=' + d.toGMTString() + ';domain=.nasdaq.com';
#   }
#   function initRecentlyViewedTracking() {
#     // Get recently viewed cookie and populate data variables
#     var recentlyViewedCookie = getCookie('recentlyViewedList');
#     if (recentlyViewedCookie && recentlyViewedCookie !== 'false') {
#       var recentlyViewedCookieArray = recentlyViewedCookie.split(',').reverse();
#       return recentlyViewedCookieArray;
#     }
#     else {
#       return '';
#     }
#   }
#   function initVolatilityTracking() {
#     var volatileCookie = getCookie('volatileMarket');
#     if (!volatileCookie) {
#       var api;
#       if (window.location.hostname.split(".")[0] === 'www') {
#         var api = 'api';
#       } else {
#         var api = 'qcapi';
#       }
#       Promise.all([
#         fetch('https://' + api + '.nasdaq.com/api/quote/indices?symbol=indu&symbol=ndx&symbol=comp&symbol=rut&symbol=spx')
#       ]).then(function (responses) {
#         // Get a JSON object from each of the responses
#         return Promise.all(responses.map(function (response) {
#           return response.json();
#         }));
#       }).then(function (data) {
#         // Grab percentage change from each index
#         var indu = parseFloat(data[0].data[0].percentageChange);
#         var comp = parseFloat(data[0].data[1].percentageChange);
#         var ndx = parseFloat(data[0].data[2].percentageChange);
#         var rut = parseFloat(data[0].data[3].percentageChange);
#         var spx = parseFloat(data[0].data[4].percentageChange);
#         var percentArray = [indu, comp, ndx, rut, spx];
#         // Check if any are up/down more than 0.5%, if so then set the cookie and set ad targeting
#         var volatileIndex = percentArray.filter(elem => {
#           return elem > 0.5 || elem < -0.5;
#         });
#         if (volatileIndex.length != 0) {
#           setCookie('volatileMarket', true, 1);
#           return 'true';
#         }
#       }).catch(function (error) {
#         // if there's an error
#       });
#     } else {
#       // Already a violatile market so just set ad targeting
#       return 'true';
#     }
#   }
#   function userAgentCheck() {
#     var userAgent = "Internal";
#     console.log(navigator.userAgent);
#     if (navigator.userAgent.indexOf("Chrome-Lighthouse") > 0 || navigator.userAgent.indexOf("New Relic") > 0) {
#       userAgent = "External";
#     }
#     return userAgent;
#   }
#   setTimeout(function () {
#     if (typeof drupalSettings != "undefined") {
#       if (drupalSettings.user_info.user_nasdaq_plus === true) {
#         googletag.pubads().setTargeting("nplus", 'Yes');
#       }
#       else {
#         googletag.pubads().setTargeting("nplus", 'No');
#       }
#       var uid = drupalSettings.user.uid;
#       var watchlist_symbols = {
#           "async": false,
#           "crossDomain": true,
#           "url": "/api/v1/watchlist/" + uid,
#           "method": "GET",
#           "headers": {
#           "content-Type" : "application/x-www-form-urlencoded",
#         }
#       }
#       if (uid != 0) { // User is signed in and has ID, pass Watchlist Symbols and Any Tipranks portfolio personal info to target
#         window.jQuery.ajax(watchlist_symbols).then(function(responseText) {
#           googletag.pubads().setTargeting("nasdaqdotcom_watchlist_symbol_list", responseText.watchlist);
#         });
#         var portfolioProfessionCookie = getCookie('portfolioProfession');
#         var portfolioAnnualIncomeCookie = getCookie('portfolioAnnualIncome');
#         var portfolioAgeCookie = getCookie('portfolioAge');
#         if (portfolioProfessionCookie) {
#           googletag.pubads().setTargeting("nasdaqdotcom_portfolio_profession", portfolioProfessionCookie);
#         }
#         if (portfolioAnnualIncomeCookie) {
#           googletag.pubads().setTargeting("nasdaqdotcom_portfolio_annual_income", portfolioAnnualIncomeCookie);
#         }
#         if (portfolioAgeCookie) {
#           googletag.pubads().setTargeting("nasdaqdotcom_portfolio_age", portfolioAgeCookie);
#         }
#       }
#     }
#   }, 2000);
#   googletag.pubads().setTargeting("nasdaqdotcom_page_instance_id", digitalData.pageInstanceID || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_page_template", digitalData.page.category.pageType || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_publisher", digitalData.page.pageInfo.publisher || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_page_name", digitalData.page.pageInfo.pageName || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_search_term", digitalData.page.pageInfo.onsiteSearchTerm || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_region_tag_list", (digitalData.page.attributes.region || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_topic_tag_list", (digitalData.page.attributes.topic || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_asset_class_tag_list", (digitalData.page.attributes.assetClass || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_quote_symbol_list", (digitalData.page.attributes.quoteSymbol || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_industry_tag_list", (digitalData.page.attributes.industry || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_audience_tag_lists", (digitalData.page.attributes.audience || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_recently_viewed_symbol_list", initRecentlyViewedTracking());
#   googletag.pubads().setTargeting("nasdaqdotcom_volatile_market", initVolatilityTracking());
#   googletag.pubads().setTargeting("nasdaqdotcom_video_type", digitalData.page.category.videoType || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_event_type", digitalData.page.category.eventType || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_user_agent", userAgentCheck());
#   googletag.pubads().setTargeting("test",test_check());
#
#
#   googletag.enableServices();
# });
# </script>
# <link rel="icon" href="https://www.nasdaq.com/sites/acquia.prod/files/favicon.ico" type="image/vnd.microsoft.icon">
#
#           <title>Quotes For Nasdaq-100 Index | Nasdaq</title>
#         <link rel="stylesheet" media="all" href="https://www.nasdaq.com/sites/acquia.prod/files/css/css_7uUWnPwQd0EFuMwCEo-XpYCBbP-hfMtTSzcEc_KKm1Y.css">
# <link rel="stylesheet" media="all" href="https://www.nasdaq.com/sites/acquia.prod/files/css/css_PV_-tObZhTPpEGVGTmGyDwjZ0HcrJEiTkugsa2KikeY.css">
#
#
#         <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">
#         <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">
#         <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">
#         <link rel="manifest" href="/manifest.json">
#         <link rel="preload" href="https://fonts.gstatic.com/s/sourcesanspro/v13/6xKydSBYKcSV-LCoeQqfX1RYOo3ik4zwlxdu3cOWxw.woff2" as="font" type="font/woff2" crossorigin="anonymous">
# <link rel="preload" href="https://fonts.gstatic.com/s/sourcesanspro/v13/6xKydSBYKcSV-LCoeQqfX1RYOo3i54rwlxdu3cOWxw.woff2" as="font" type="font/woff2" crossorigin="anonymous">
# <link rel="preload" href="https://fonts.gstatic.com/s/sourcesanspro/v13/6xK3dSBYKcSV-LCoeQqfX1RYOo3qOK7lujVj9w.woff2" as="font" type="font/woff2" crossorigin="anonymous">
# <link rel="preload" href="https://use.typekit.net/af/150b2d/00000000000000003b9afb65/27/l?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&amp;fvd=n1&amp;v=3" as="font" type="font/woff2" crossorigin="anonymous">
# <link rel="preload" href="https://use.typekit.net/af/7efd4b/00000000000000003b9afb67/27/l?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&amp;fvd=n3&amp;v=3" as="font" type="font/woff2" crossorigin="anonymous">
# <link rel="preload" href="https://use.typekit.net/af/4e2d77/00000000000000003b9afb6b/27/l?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&amp;fvd=n6&amp;v=3" as="font" type="font/woff2" crossorigin="anonymous">
# <link rel="preload" href="https://www.nasdaq.com/themes/nsdq/dist/assets/fonts/Roboto-Regular.woff2" as="font" type="font/woff2" crossorigin="anonymous">
# <link rel="preload" href="https://www.nasdaq.com/themes/nsdq/dist/assets/fonts/Roboto-Light.woff" as="font" type="font/woff" crossorigin="anonymous">
# <link rel="preload" href="https://www.nasdaq.com/themes/nsdq/dist/assets/fonts/Roboto-Bold.woff2" as="font" type="font/woff2" crossorigin="anonymous">
# <link rel="preload" href="https://www.nasdaq.com/themes/nsdq/dist/assets/fonts/Roboto-Medium.woff2" as="font" type="font/woff2" crossorigin="anonymous">
# <link rel="preload" href="https://www.nasdaq.com/themes/nsdq/dist/assets/fonts/nasdaq-icons.ttf?ck9pto" as="font" type="font/ttf" crossorigin="anonymous">
# <link rel="preload" href="https://nd.nasdaq.com/js/forms2/css/forms2.css" as="style">
# <link rel="preload" href="https://nd.nasdaq.com/js/forms2/css/forms2-theme-plain.css" as="style">        <link rel="dns-prefetch" href="https://www.googleadservices.com">
#         <link rel="dns-prefetch" href="https://micro.rubiconproject.com">
#         <link rel="dns-prefetch" href="https://securepubads.g.doubleclick.net">
#         <meta name="msapplication-TileColor" content="#da532c">
#         <meta name="theme-color" content="#ffffff">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#         <meta name="google-site-verification" content="A4ZdzztVttv1nCpL1SePVC3K2K">
#
#         <link rel="dns-prefetch" href="">
#         <script src="https://cdn.jwplayer.com/libraries/kAO2Gezz.js" defer=""></script>
#         <script src="https://config.aps.amazon-adsystem.com/configs/3444" type="text/javascript" async="async"></script><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><script src="https://securepubads.g.doubleclick.net/pagead/managed/js/gpt/m202311150101/pubads_impl.js" async=""></script><script src="//secure.cdn.fastclick.net/js/pubcid/latest/pubcid.min.js"></script><script src="https://tags.crwdcntrl.net/lt/c/16576/sync.min.js"></script><script src="//cdn.id5-sync.com/api/1.0/id5-api.js"></script><script async="" src="https://fundingchoicesmessages.google.com/i/3244?ers=3"></script><script type="text/javascript" src="//ad.wsod.com/site/2caa62b3a3a0755e2cda9deea9070934/1.0.async/1701451457;0,0,0;2240x1400x1;https%3A_@2F_@2Fwww.nasdaq.com_@2Fmarket-activity_@2Fquotes_@2Fnasdaq-ndx-index;;;" async="async"></script><script src="https://cdn.cookielaw.org/scripttemplates/202310.1.0/otBannerSdk.js" async="" type="text/javascript"></script><script type="text/javascript" async="" src="https://cdn.cookielaw.org/scripttemplates/202310.1.0/otTCF.js"></script><link id="mktoForms2BaseStyle" rel="stylesheet" type="text/css" href="https://nd.nasdaq.com/js/forms2/css/forms2.css"><link id="mktoForms2ThemeStyle" rel="stylesheet" type="text/css" href="https://nd.nasdaq.com/js/forms2/css/forms2-theme-plain.css" disabled=""><script id="addWebPageUrl">MktoForms2.whenReady(function(form) {form.addHiddenFields({'webPageURL':'https://www.nasdaq.com/market-activity/quotes/nasdaq-ndx-index'}); form.submittable(true); });</script><script async="" src="https://fundingchoicesmessages.google.com/f/AGSKWxUKQcZ-kxTSUDLsibMIQn_eXYH972hwf5Co_OYP5dQnOfoZbQYNMDgCcjSdCO8kq9mYI-g0p7CWAWmSk_e9hWZHtfmZWLR6YN_lbkmLgboFMgTqPDD1CptOo7xMUaKep3A7uxXfuw==?fccs="></script><style id="onetrust-style">#onetrust-banner-sdk{-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}#onetrust-banner-sdk .onetrust-vendors-list-handler{cursor:pointer;color:#1f96db;font-size:inherit;font-weight:bold;text-decoration:none;margin-left:5px}#onetrust-banner-sdk .onetrust-vendors-list-handler:hover{color:#1f96db}#onetrust-banner-sdk:focus{outline:2px solid #000;outline-offset:-2px}#onetrust-banner-sdk a:focus{outline:2px solid #000}#onetrust-banner-sdk #onetrust-accept-btn-handler,#onetrust-banner-sdk #onetrust-reject-all-handler,#onetrust-banner-sdk #onetrust-pc-btn-handler{outline-offset:1px}#onetrust-banner-sdk.ot-bnr-w-logo .ot-bnr-logo{height:64px;width:64px}#onetrust-banner-sdk .ot-tcf2-vendor-count.ot-text-bold{font-weig ...
#         #onetrust-consent-sdk #onetrust-banner-sdk {background-color: #FFFFFF;}
#             #onetrust-consent-sdk #onetrust-policy-title,
#                     #onetrust-consent-sdk #onetrust-policy-text,
#                     #onetrust-consent-sdk .ot-b-addl-desc,
#                     #onetrust-consent-sdk .ot-dpd-desc,
#                     #onetrust-consent-sdk .ot-dpd-title,
#                     #onetrust-consent-sdk #onetrust-policy-text *:not(.onetrust-vendors-list-handler),
#                     #onetrust-consent-sdk .ot-dpd-desc *:not(.onetrust-vendors-list-handler),
#                     #onetrust-consent-sdk #onetrust-banner-sdk #banner-options *,
#                     #onetrust-banner-sdk .ot-cat-header,
#                     #onetrust-banner-sdk .ot-optout-signal
#                     {
#                         color: #696969;
#                     }
#             #onetrust-consent-sdk #onetrust-banner-sdk .banner-option-details {
#                     background-color: #E9E9E9;}
#              #onetrust-consent-sdk #onetrust-banner-sdk a[href],
#                     #onetrust-consent-sdk #onetrust-banner-sdk a[href] font,
#                     #onetrust-consent-sdk #onetrust-banner-sdk .ot-link-btn
#                         {
#                             color: #3860BE;
#                         }#onetrust-consent-sdk #onetrust-accept-btn-handler,
#                          #onetrust-banner-sdk #onetrust-reject-all-handler {
#                             background-color: #346E4A;border-color: #346E4A;
#                 color: #FFFFFF;
#             }
#             #onetrust-consent-sdk #onetrust-banner-sdk *:focus,
#             #onetrust-consent-sdk #onetrust-banner-sdk:focus {
#                outline-color: #000000;
#                outline-width: 1px;
#             }
#             #onetrust-consent-sdk #onetrust-pc-btn-handler,
#             #onetrust-consent-sdk #onetrust-pc-btn-handler.cookie-setting-link {
#                 color: #346E4A; border-color: #346E4A;
#                 background-color:
#                 #FFFFFF;
#             }/**
#  * Int OneTrust GDPR override styles
#  */
#
# #onetrust-consent-sdk * {
#   font-family: Inter,system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica,Arial,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol !important;
#   letter-spacing: normal !important;
#   outline: none !important;
# }
#
# #ot-sdk-btn.ot-sdk-show-settings {
#   border: none;
#   padding: 0;
#   color: #a7a9ac;
#   font-family: 'Source Sans Pro', sans-serif;
#   font-weight: 600;
#   font-size: 16px;
#   letter-spacing: 1.5px;
#   text-transform: none;
#   text-decoration: none;
#   text-transform: uppercase;
#  }
#
#  #ot-sdk-btn.ot-sdk-show-settings:hover {
#   color: #a7a9ac;
#   background-color: inherit;
#   text-decoration: underline;
#  }
#
# #onetrust-consent-sdk #onetrust-banner-sdk #onetrust-policy-text,
# #onetrust-consent-sdk #onetrust-banner-sdk .ot-dpd-container {
#   margin-left: 24px;
#   margin-right: 24px;
# }
#
# #onetrust-consent-sdk #onetrust-banner-sdk #onetrust-policy-title {
#   padding-left: 24px;
# }
#
# #onetrust-consent-sdk #onetrust-banner-sdk .ot-dpd-container {
#   margin-top: .75rem !important;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk #ot-pc-content h3,
# #onetrust-consent-sdk #onetrust-pc-sdk #ot-pc-content #ot-pc-title,
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-acc-hdr h4,
# #onetrust-consent-sdk #onetrust-banner-sdk #onetrust-policy-title,
# #onetrust-consent-sdk #onetrust-banner-sdk .ot-dpd-title {
#   font-size: 1rem;
#   font-weight: 600;
#   color: #08082A;
# }
#
# #onetrust-consent-sdk #onetrust-banner-sdk p,
# #onetrust-consent-sdk #onetrust-banner-sdk .ot-dpd-desc button,
# #onetrust-consent-sdk #onetrust-pc-sdk #ot-pc-content #ot-pc-desc,
# #onetrust-pc-sdk .ot-cat-grp .ot-acc-hdr .ot-always-active,
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-acc-grpcntr p {
#   font-size: .75rem;
#   font-weight: normal;
#   line-height: 1rem;
# }
#
# #onetrust-consent-sdk #onetrust-banner-sdk #onetrust-button-group {
#   display: flex !important;
#   justify-content: center;
#   white-space: nowrap;
#   margin: 0 !important;
#   width: auto !important;
#   display: inline-block;
# }
#
# @media only screen and (max-width: 425px) {
#   #onetrust-consent-sdk #onetrust-banner-sdk #onetrust-button-group {
#     flex-direction: column;
#   }
# }
#
# #onetrust-consent-sdk #onetrust-banner-sdk #onetrust-button-group .banner-actions-container {
#   order: 1;
#   width: auto;
# }
#
# @media only screen and (min-width: 426px) {
#   #onetrust-consent-sdk #onetrust-banner-sdk #onetrust-button-group .cookie-setting-link {
#     margin-right: 1.5rem;
#   }
# }
#
# #onetrust-consent-sdk #onetrust-banner-sdk p {
#   color: #6E6E83;
# }
#
# #onetrust-consent-sdk #onetrust-banner-sdk .ot-dpd-desc button {
#   color: #0092BC;
#   display: inline-block;
#   margin-top: 0;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk button.save-preference-btn-handler.onetrust-close-btn-handler:not(#clear-filters-handler):not(.ot-close-icon):not(#filter-btn-handler):not(.ot-remove-objection-handler):not(.ot-obj-leg-btn-handler):not([aria-expanded]):not(.ot-link-btn) {
#   background: #f5f5fa;
#   border-color: #08062a;
#   color: #08062a;
# }
#
# #onetrust-consent-sdk #accept-recommended-btn-handler,
# #onetrust-consent-sdk .save-preference-btn-handler.onetrust-close-btn-handler,
# #onetrust-consent-sdk #onetrust-accept-btn-handler,
# #onetrust-consent-sdk #onetrust-pc-btn-handler.cookie-setting-link,
# #onetrust-consent-sdk #onetrust-pc-sdk button:not(#clear-filters-handler):not(.ot-close-icon):not(#filter-btn-handler):not(.ot-remove-objection-handler):not(.ot-obj-leg-btn-handler):not([aria-expanded]):not(.ot-link-btn),
# #onetrust-consent-sdk #onetrust-pc-sdk ul li .ot-leg-btn-container .ot-inactive-leg-btn,
# #onetrust-consent-sdk #onetrust-pc-sdk ul li .ot-leg-btn-container .ot-active-leg-btn {
#   /* display: inline-flex; */
#   align-items: center;
#   background: #f5f5fa;
#   box-shadow: 0.25rem 0.25rem 0 -0.0625rem #f5f5fa, 0.25rem 0.25rem 0 #08062a;
#   border-width: 0.0625rem;
#   border-style: solid;
#   border-color: #08062a;
#   color: #08062a;
#   border-radius: 0.125rem;
#   padding: calc(.5rem * 1.5) calc(.5rem * 2.5);
#   cursor: pointer;
#   font-family: Inter,system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica,Arial,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol;
#   line-height: 1.5;
#   font-weight: 600;
#   font-size: 12px;
#   text-decoration: none;
#   white-space: break-spaces;
#   transition: all 125ms ease-out;
# }
#
# #onetrust-banner-sdk button#onetrust-accept-btn-handler:hover,
# #onetrust-banner-sdk button#onetrust-pc-btn-handler.cookie-setting-link:hover,
# #onetrust-consent-sdk #onetrust-pc-sdk button#accept-recommended-btn-handler:hover:not(#clear-filters-handler):not(.ot-close-icon):not(#filter-btn-handler):not(.ot-remove-objection-handler):not(.ot-obj-leg-btn-handler):not([aria-expanded]):not(.ot-link-btn),
# #onetrust-consent-sdk #onetrust-pc-sdk button#accept-recommended-btn-handler:focus:not(#clear-filters-handler):not(.ot-close-icon):not(#filter-btn-handler):not(.ot-remove-objection-handler):not(.ot-obj-leg-btn-handler):not([aria-expanded]):not(.ot-link-btn),
# #onetrust-consent-sdk #onetrust-pc-sdk button.save-preference-btn-handler.onetrust-close-btn-handler:hover:not(#clear-filters-handler):not(.ot-close-icon):not(#filter-btn-handler):not(.ot-remove-objection-handler):not(.ot-obj-leg-btn-handler):not([aria-expanded]):not(.ot-link-btn),
# #onetrust-consent-sdk #onetrust-pc-sdk button.save-preference-btn-handler.onetrust-close-btn-handler:focus:not(#clear-filters-handler):not(.ot-close-icon):not(#filter-btn-handler):not(.ot-remove-objection-handler):not(.ot-obj-leg-btn-handler):not([aria-expanded]):not(.ot-link-btn),
# #onetrust-consent-sdk #onetrust-pc-sdk ul li .ot-leg-btn-container .ot-inactive-leg-btn:hover,
# #onetrust-consent-sdk #onetrust-pc-sdk ul li .ot-leg-btn-container .ot-active-leg-btn:hover {
#   color: #08062a;
#   background: #0092bc;
#   border-color: #0092bc;
#   box-shadow: 0 0 0 0 #f5f5fa,0 0 0 #08062a;
#   text-decoration: none;
#   opacity: 1;
# }
#
# #onetrust-banner-sdk #accept-recommended-btn-handler,
# #onetrust-banner-sdk button#onetrust-accept-btn-handler,
# #onetrust-consent-sdk #onetrust-pc-sdk button#accept-recommended-btn-handler:not(#clear-filters-handler):not(.ot-close-icon):not(#filter-btn-handler):not(.ot-remove-objection-handler):not(.ot-obj-leg-btn-handler):not([aria-expanded]):not(.ot-link-btn),
# #onetrust-consent-sdk #onetrust-pc-sdk ul li .ot-leg-btn-container .ot-active-leg-btn {
#   color: #ffffff;
#   background: #08062a;
#   border-color: #08062a;
#   box-shadow: 0.25rem 0.25rem 0 #0092bc;
# }
#
# /**
#  * Show Purposes modal
#  */
#
# #onetrust-consent-sdk #onetrust-pc-sdk [aria-expanded="true"] + .ot-acc-hdr h4 {
#   color: #8050ED;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk #ot-pc-content h3,
# #onetrust-consent-sdk #onetrust-pc-sdk #ot-pc-content #ot-pc-title {
#   line-height: 24px;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-acc-hdr h4 {
#   line-height: 22px;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk #ot-pc-content #ot-pc-desc,
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-acc-grpcntr p {
#   color: #6E6E83;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-accordion-layout .ot-acc-grpcntr.ot-acc-txt {
#   background-color: #ffffff;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk #ot-pc-content #ot-pc-desc br {
#   display: none;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk #ot-pc-desc .privacy-notice-link,
# #onetrust-pc-sdk .ot-cat-grp .ot-acc-hdr .ot-always-active {
#   color: #0092BC;
# }
#
# #onetrust-pc-sdk .ot-pc-footer .ot-btn-container {
#   text-align: left;
# }
#
# #onetrust-pc-sdk .ot-acc-hdr .ot-plus-minus {
#   border: 1px solid #8050ED;
#   border-radius: 100%;
#   margin-right: .5rem;
#   top: 4px;
# }
#
# #onetrust-pc-sdk button[aria-expanded=true] + .ot-acc-hdr .ot-plus-minus,
# #onetrust-pc-sdk .ot-acc-hdr .ot-plus-minus span {
#   background: #9A7DF4;
# }
#
# #onetrust-pc-sdk button[aria-expanded=true] + .ot-acc-hdr .ot-plus-minus {
#   border: 1px solid #9A7DF4;
# }
#
# #onetrust-pc-sdk button[aria-expanded=true] + .ot-acc-hdr .ot-plus-minus span {
#   background: #ffffff;
# }
#
# #onetrust-pc-sdk .ot-accordion-layout button[aria-expanded=true] + .ot-acc-hdr {
#   border-bottom: 1px solid #C6C6D0;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-accordion-layout.ot-cat-item {
#   border: 1px solid #C6C6D0;
#   border-top: none;
#   border-radius: 0;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-accordion-layout.ot-cat-item:first-of-type {
#   border-top: 1px solid #C6C6D0;
#   border-radius: 4px 4px 0 0;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-accordion-layout.ot-cat-item:last-of-type {
#   border-radius: 0 0 4px 4px;
# }
#
# #onetrust-pc-sdk .ot-switch .ot-switch-nob {
#   background-color: #E6E6E6;
#   border: 0;
# }
#
# #onetrust-pc-sdk .ot-switch .ot-switch-nob:before,
# #onetrust-pc-sdk .ot-acc-hdr .ot-tgl input:checked+.ot-switch .ot-switch-nob:before,
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-tgl input:checked+.ot-switch .ot-switch-nob:before {
#   background-color: #ffffff;
#   bottom: 2px;
# }
#
# #onetrust-pc-sdk .ot-switch .ot-switch-nob:before {
#   left: 2px;
# }
#
# #onetrust-pc-sdk .ot-acc-hdr .ot-tgl input:checked+.ot-switch .ot-switch-nob:before {
#   right: 2px;
# }
#
# #onetrust-pc-sdk .ot-acc-hdr .ot-tgl input:focus+.ot-switch {
#   outline: none;
# }
#
# #onetrust-pc-sdk .ot-acc-hdr .ot-tgl input:checked+.ot-switch .ot-switch-nob,
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-tgl input:checked+.ot-switch .ot-switch-nob {
#   background-color: #9A7DF4;
#   border: none;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk #ot-pc-content {
#   margin-left: 24px;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-pc-header {
#   padding-left: 0;
#   border-bottom: 1px solid #cccccc;
#   margin: 0 24px;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk #ot-pc-content {
#   padding-right: 7px;
#   width: calc(100% - 37px);
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-pc-footer {
#   border: none;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-pc-footer .ot-btn-container {
#   border-top: 1px solid #cccccc;
#   margin: 0 24px;
# }
#
# /**
#  * Additional custom styles
#  */
#
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-vlst-cntr .category-vendors-list-handler,
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-vlst-cntr .category-vendors-list-handler + a {
#   color: #0092BC;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk ul li .ot-leg-btn-container .ot-active-leg-btn + button {
#   color: #0092BC !important;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk ul li h5 {
#   font-size: 1rem;
#   font-weight: 600;
#   color: #08082A;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk ul li .ot-leg-btn-container .ot-inactive-leg-btn,
# #onetrust-consent-sdk #onetrust-pc-sdk ul li .ot-leg-btn-container .ot-active-leg-btn {
#   display: inline-flex;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk ul li .ot-leg-btn-container .ot-inactive-leg-btn span {
#   font-weight: 600;
#   line-height: normal;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk li.ot-subgrp {
#   margin-left: 0;
#   margin-bottom: 1rem;
# }
#
# /**
#  * Vendors List modal
#  */
#
# #onetrust-pc-sdk #ot-back-arw path {
#   fill: #08062a;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk #ot-pc-lst #ot-pc-hdr #ot-lst-title h3,
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-sdk-column ul li .ot-acc-hdr h3 {
#   color: #08062a !important;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk ul li .ot-acc-hdr h3 {
#   font-size: 1rem;
#   font-weight: 600;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-ven-hdr .ot-ven-link {
#   color: #0092BC;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk #filter-btn-handler,
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-chkbox input:checked~label::before {
#   background-color: #9A7DF4;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-chkbox label::before {
#   border: 1px solid #9A7DF4;
#   outline: none;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk *:not(#vendor-search-handler):focus,
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-vlst-cntr > a:focus {
#   outline: none !important;
#   border: 0 !important;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-ven-item .ot-acc-txt .ot-ven-dets {
#   background-color: #f5f5fa;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk :not(.ot-leg-btn-container)>button:not(.ot-link-btn):hover,
# #onetrust-consent-sdk #onetrust-pc-sdk :not(.ot-leg-btn-container)>button:not(.ot-link-btn):focus,
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-ven-dets .ot-ven-pur h4 {
#   border: 0;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk .ot-ven-dets .ot-ven-disc:not(:first-child) {
#   border: 0 !important;
# }
#
# #onetrust-consent-sdk #onetrust-pc-sdk input[type="text"]:focus {
#   border: 1px solid #ccc;
# ...
#                         </svg>
#                         <span>Object to Legitimate Interests
#                         </span>
#                     </button>
#                     <button class="ot-remove-objection-handler" data-style="color:#346E4A; display:none;" style="color:#346E4A; display:none;">
#                         Remove Objection
#                     </button>
#                 </div></li></ul></div><div class="ot-subgrp-cntr"><ul class="ot-subgrps"><li class="ot-subgrp" data-optanongroupid="IAB2V2_11"><h5>Use limited data to select content<span class="ot-pur-vdr-count"> 104 partners can use this purpose </span></h5><div class="ot-tgl-cntr ot-subgrp-tgl"><div class="ot-tgl"><input type="checkbox" name="switch" id="ot-sub-group-id-IAB2V2_11" aria-checked="false" role="switch" data-optanongroupid="IAB2V2_11" class="cookie-subgroup-handler" aria-label="Use limited data to select content"> <label class="ot-switch" for="ot-sub-group-id-IAB2V2_11"><span class="ot-switch-nob" aria-checked="false" role="switch"></span> <span class="ot-label-txt">Switch Label</span></label> </div></div><p class="ot-subgrp-desc">Content presented to you on this service can be based on limited data, such as the website or app you are using, your non-precise location, your device type, or which content you are (or have been) interacting with (for example, to limit the number of times a video or an article is presented to you).</p><button class="ot-link-btn ot-pgph-link ot-pgph-link-subgroup" aria-label="View Illustrations" data-parent-id="IAB2V2_11">View Illustrations&nbsp;</button><div class="ot-leg-btn-container" data-group-id="IAB2V2_11" data-el-id="IAB2V2_11-leg-out" is-vendor="false">
#                     <button class="ot-obj-leg-btn-handler ot-leg-int-enabled ot-inactive-leg-btn">
#                         <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 0 512 512">
#                             <path fill="#FFFFFF" d="M173.898 439.404l-166.4-166.4c-9.997-9.997-9.997-26.206 0-36.204l36.203-36.204c9.997-9.998 26.207-9.998 36.204 0L192 312.69 432.095 72.596c9.997-9.997 26.207-9.997 36.204 0l36.203 36.204c9.997 9.997 9.997 26.206 0 36.204l-294.4 294.401c-9.998 9.997-26.207 9.997-36.204-.001z"></path>
#                         </svg>
#                         <span>Object to Legitimate Interests
#                         </span>
#                     </button>
#                     <button class="ot-remove-objection-handler" data-style="color:#346E4A; display:none;" style="color:#346E4A; display:none;">
#                         Remove Objection
#                     </button>
#                 </div></li></ul></div><div class="ot-vlst-cntr"><button class="ot-link-btn category-vendors-list-handler" aria-label="IAB Vendor Details button opens Vendor List menu" data-parent-id="V2STACK42">List of IAB Vendors‎</button></div></div></div><div class="ot-accordion-layout ot-cat-item ot-vs-config" data-optanongroupid="ISF2V2_1"><button aria-expanded="false" ot-accordion="true" aria-controls="ot-desc-id-ISF2V2_1" aria-labelledby="ot-header-id-ISF2V2_1"></button><!-- Accordion header --><div class="ot-acc-hdr"><div class="ot-plus-minus"><span></span><span></span></div><h4 class="ot-cat-header" id="ot-header-id-ISF2V2_1">Use precise geolocation data<span class="ot-pur-vdr-count"> 250 partners can use this purpose </span></h4><div class="ot-tgl"><input type="checkbox" name="ot-group-id-ISF2V2_1" id="ot-group-id-ISF2V2_1" aria-checked="false" role="switch" class="category-switch-handler" data-optanongroupid="ISF2V2_1" aria-labelledby="ot-header-id-ISF2V2_1"> <label class="ot-switch" for="ot-group-id-ISF2V2_1"><span class="ot-switch-nob" aria-checked="false" role="switch" aria-label="Use precise geolocation data"></span> <span class="ot-label-txt">Use precise geolocation data</span></label> </div></div><!-- accordion detail --><div class="ot-acc-grpcntr ot-acc-txt"><p class="ot-acc-grpdesc ot-category-desc" id="ot-desc-id-ISF2V2_1">With your acceptance, your precise location (within a radius of less than 500 metres) may be used in support of the purposes explained in this notice.</p><div class="ot-vlst-cntr"><button class="ot-link-btn category-vendors-list-handler" aria-label="IAB Vendor Details button opens Vendor List menu" data-parent-id="ISF2V2_1">List of IAB Vendors‎</button></div></div></div><div class="ot-accordion-layout ot-cat-item ot-vs-config" data-optanongroupid="ISF2V2_2"><button aria-expanded="false" ot-accordion="true" aria-controls="ot-desc-id-ISF2V2_2" aria-labelledby="ot-header-id-ISF2V2_2"></button><!-- Accordion header --><div class="ot-acc-hdr"><div class="ot-plus-minus"><span></span><span></span></div><h4 class="ot-cat-header" id="ot-header-id-ISF2V2_2">Actively scan device characteristics for identification<span class="ot-pur-vdr-count"> 120 partners can use this purpose </span></h4><div class="ot-tgl"><input type="checkbox" name="ot-group-id-ISF2V2_2" id="ot-group-id-ISF2V2_2" aria-checked="false" role="switch" class="category-switch-handler" data-optanongroupid="ISF2V2_2" aria-labelledby="ot-header-id-ISF2V2_2"> <label class="ot-switch" for="ot-group-id-ISF2V2_2"><span class="ot-switch-nob" aria-checked="false" role="switch" aria-label="Actively scan device characteristics for identification"></span> <span class="ot-label-txt">Actively scan device characteristics for identification</span></label> </div></div><!-- accordion detail --><div class="ot-acc-grpcntr ot-acc-txt"><p class="ot-acc-grpdesc ot-category-desc" id="ot-desc-id-ISF2V2_2">With your acceptance, certain characteristics specific to your device might be requested and used to distinguish it from other devices (such as the installed fonts or plugins, the resolution of your screen) in support of the purposes explained in this notice.</p><div class="ot-vlst-cntr"><button class="ot-link-btn category-vendors-list-handler" aria-label="IAB Vendor Details button opens Vendor List menu" data-parent-id="ISF2V2_2">List of IAB Vendors‎</button></div></div></div><div class="ot-accordion-layout ot-cat-item ot-vs-config" data-optanongroupid="ISP2V2_1"><button aria-expanded="false" ot-accordion="true" aria-controls="ot-desc-id-ISP2V2_1" aria-labelledby="ot-header-id-ISP2V2_1"></button><!-- Accordion header --><div class="ot-acc-hdr ot-always-active-group"><div class="ot-plus-minus"><span></span><span></span></div><h4 class="ot-cat-header" id="ot-header-id-ISP2V2_1">Ensure security, prevent and detect fraud, and fix errors<span class="ot-pur-vdr-count"> 480 partners can use this purpose </span></h4><div class="ot-always-active">Always Active</div> ...
#                     l-21.409-21.416C323.432,3.521,314.817,0,304.637,0s-18.791,3.521-25.841,10.561L92.649,196.425
#                     c-7.044,7.043-10.566,15.656-10.566,25.841s3.521,18.791,10.566,25.837l186.146,185.864c7.05,7.043,15.66,10.564,25.841,10.564
#                     s18.795-3.521,25.834-10.564l21.409-21.412c7.05-7.039,10.567-15.604,10.567-25.697c0-10.085-3.518-18.746-10.567-25.978
#                     L213.13,222.409z"></path></g></svg></button><h3>Cookie List</h3></div><div class="ot-lst-subhdr"><div class="ot-search-cntr"><p role="status" class="ot-scrn-rdr"></p><input id="vendor-search-handler" type="text" name="vendor-search-handler" placeholder="Search…" aria-label="Cookie list search"> <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 -30 110 110" aria-hidden="true"><title>Search Icon</title><path fill="#2e3644" d="M55.146,51.887L41.588,37.786c3.486-4.144,5.396-9.358,5.396-14.786c0-12.682-10.318-23-23-23s-23,10.318-23,23
#             s10.318,23,23,23c4.761,0,9.298-1.436,13.177-4.162l13.661,14.208c0.571,0.593,1.339,0.92,2.162,0.92
#             c0.779,0,1.518-0.297,2.079-0.837C56.255,54.982,56.293,53.08,55.146,51.887z M23.984,6c9.374,0,17,7.626,17,17s-7.626,17-17,17
#             s-17-7.626-17-17S14.61,6,23.984,6z"></path></svg></div><div class="ot-fltr-cntr"><button id="filter-btn-handler" aria-label="Filter" aria-haspopup="true"><svg role="presentation" aria-hidden="true" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 0 402.577 402.577" xml:space="preserve"><title>Filter Icon</title><g><path fill="#fff" d="M400.858,11.427c-3.241-7.421-8.85-11.132-16.854-11.136H18.564c-7.993,0-13.61,3.715-16.846,11.136
#       c-3.234,7.801-1.903,14.467,3.999,19.985l140.757,140.753v138.755c0,4.955,1.809,9.232,5.424,12.854l73.085,73.083
#       c3.429,3.614,7.71,5.428,12.851,5.428c2.282,0,4.66-0.479,7.135-1.43c7.426-3.238,11.14-8.851,11.14-16.845V172.166L396.861,31.413
#       C402.765,25.895,404.093,19.231,400.858,11.427z"></path></g></svg></button></div><div id="ot-anchor"></div><section id="ot-fltr-modal"><div id="ot-fltr-cnt"><button id="clear-filters-handler">Clear</button><div class="ot-fltr-scrlcnt ot-pc-scrollbar"><div class="ot-fltr-opts"><div class="ot-fltr-opt"><div class="ot-chkbox"><input id="chkbox-id" type="checkbox" aria-checked="false" class="category-filter-handler"> <label for="chkbox-id"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div></div></div><div class="ot-fltr-btns"><button id="filter-apply-handler">Apply</button> <button id="filter-cancel-handler">Cancel</button></div></div></div></section></div></div><section id="ot-lst-cnt" class="ot-host-cnt ot-pc-scrollbar"><div id="ot-sel-blk"><div class="ot-sel-all"><div class="ot-sel-all-hdr"><span class="ot-consent-hdr">Consent</span> <span class="ot-li-hdr">Leg.Interest</span></div><div class="ot-sel-all-chkbox"><div class="ot-chkbox" id="ot-selall-hostcntr"><input id="select-all-hosts-groups-handler" type="checkbox" aria-checked="false"> <label for="select-all-hosts-groups-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div><div class="ot-chkbox" id="ot-selall-vencntr"><input id="select-all-vendor-groups-handler" type="checkbox" aria-checked="false"> <label for="select-all-vendor-groups-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div><div class="ot-chkbox" id="ot-selall-licntr"><input id="select-all-vendor-leg-handler" type="checkbox" aria-checked="false"> <label for="select-all-vendor-leg-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div></div></div></div><div class="ot-sdk-row"><div class="ot-sdk-column"><ul id="ot-ven-lst"></ul></div></div></section></section><div class="ot-pc-footer"><div class="ot-btn-container"> <button class="save-preference-btn-handler onetrust-close-btn-handler">Confirm My Choices</button></div><!-- Footer logo --><div class="ot-pc-footer-logo"><a href="https://www.onetrust.com/products/cookie-consent/" target="_blank" rel="noopener noreferrer" aria-label="Powered by OneTrust Opens in a new Tab"><img alt="Powered by Onetrust" src="https://cdn.cookielaw.org/logos/static/powered_by_logo.svg" title="Powered by OneTrust Opens in a new Tab"></a></div></div><!-- Cookie subgroup container --><!-- Vendor list link --><!-- Cookie lost link --><!-- Toggle HTML element --><!-- Checkbox HTML --><!-- plus minus--><!-- Arrow SVG element --><!-- Accordion basic element --><span class="ot-scrn-rdr" aria-atomic="true" aria-live="polite"></span><!-- Vendor Service container and item template --></div><iframe class="ot-text-resize" sandbox="allow-same-origin" title="onetrust-text-resize" style="position: absolute; top: -50000px; width: 100em;" aria-hidden="true"></iframe></div></div></body></html>
# call nasdaq-100 tickers
# amount of tickers:  83
# getting tickers finished
# [<__main__.Tickerinfo object at 0x00000256DF53ADD0>, <__main__.Tickerinfo object at 0x00000256DF216500>, <__main__.Tickerinfo object at 0x00000256DF47AEF0>, <__main__.Tickerinfo object at 0x00000256E4121420>, <__main__.Tickerinfo object at 0x00000256DF47BEE0>, <__main__.Tickerinfo object at 0x00000256E3FCF400>, <__main__.Tickerinfo object at 0x00000256E3FCD4B0>, <__main__.Tickerinfo object at 0x00000256E00DB8E0>, <__main__.Tickerinfo object at 0x00000256E3FCF340>, <__main__.Tickerinfo object at 0x00000256E3FCD420>, <__main__.Tickerinfo object at 0x00000256DF43EA10>, <__main__.Tickerinfo object at 0x00000256DF43E8C0>, <__main__.Tickerinfo object at 0x00000256DF43EB00>, <__main__.Tickerinfo object at 0x00000256DF43E4A0>, <__main__.Tickerinfo object at 0x00000256DF43FB80>, <__main__.Tickerinfo object at 0x00000256DF43F310>, <__main__.Tickerinfo object at 0x00000256DF43EF80>, <__main__.Tickerinfo object at 0x00000256DF43DD20>, <__main__.Tickerinfo object at 0x00000256DF43F9D0>, <__main__.Tickerinfo object at 0x00000256DF43F1C0>, <__main__.Tickerinfo object at 0x00000256DF43E6B0>, <__main__.Tickerinfo object at 0x00000256DF43E0E0>, <__main__.Tickerinfo object at 0x00000256DF43DC90>, <__main__.Tickerinfo object at 0x00000256DF43DBA0>, <__main__.Tickerinfo object at 0x00000256E3FCF730>, <__main__.Tickerinfo object at 0x00000256DF43F790>, <__main__.Tickerinfo object at 0x00000256DF43E9B0>, <__main__.Tickerinfo object at 0x00000256DF43F7F0>, <__main__.Tickerinfo object at 0x00000256E45296F0>, <__main__.Tickerinfo object at 0x00000256DF43F400>, <__main__.Tickerinfo object at 0x00000256B7080880>, <__main__.Tickerinfo object at 0x00000256B7081BA0>, <__main__.Tickerinfo object at 0x00000256E012C7F0>, <__main__.Tickerinfo object at 0x00000256E012C400>, <__main__.Tickerinfo object at 0x00000256B7080B50>, <__main__.Tickerinfo object at 0x00000256B7083FA0>, <__main__.Tickerinfo object at 0x00000256E012CA30>, <__main__.Tickerinfo object at 0x00000256E012C100>, <__main__.Tickerinfo object at 0x00000256E4716260>, <__main__.Tickerinfo object at 0x00000256E4715C00>, <__main__.Tickerinfo object at 0x00000256E4715AB0>, <__main__.Tickerinfo object at 0x00000256E4715A50>, <__main__.Tickerinfo object at 0x00000256E4715B40>, <__main__.Tickerinfo object at 0x00000256E4715780>, <__main__.Tickerinfo object at 0x00000256E4715720>, <__main__.Tickerinfo object at 0x00000256E4715C60>, <__main__.Tickerinfo object at 0x00000256E4715660>, <__main__.Tickerinfo object at 0x00000256E4715600>, <__main__.Tickerinfo object at 0x00000256E4715A20>, <__main__.Tickerinfo object at 0x00000256E4715B10>, <__main__.Tickerinfo object at 0x00000256E47154E0>, <__main__.Tickerinfo object at 0x00000256E4715480>, <__main__.Tickerinfo object at 0x00000256E4715420>, <__main__.Tickerinfo object at 0x00000256E47153C0>, <__main__.Tickerinfo object at 0x00000256E4715360>, <__main__.Tickerinfo object at 0x00000256E4715300>, <__main__.Tickerinfo object at 0x00000256E47152A0>, <__main__.Tickerinfo object at 0x00000256E4715240>, <__main__.Tickerinfo object at 0x00000256E47153F0>, <__main__.Tickerinfo object at 0x00000256E4715690>, <__main__.Tickerinfo object at 0x00000256E4714460>, <__main__.Tickerinfo object at 0x00000256E47143A0>, <__main__.Tickerinfo object at 0x00000256E4714340>, <__main__.Tickerinfo object at 0x00000256E4715210>, <__main__.Tickerinfo object at 0x00000256E4715270>, <__main__.Tickerinfo object at 0x00000256E47150C0>, <__main__.Tickerinfo object at 0x00000256E4715060>, <__main__.Tickerinfo object at 0x00000256E4715000>, <__main__.Tickerinfo object at 0x00000256E4714FA0>, <__main__.Tickerinfo object at 0x00000256E4714F40>, <__main__.Tickerinfo object at 0x00000256E4714EE0>, <__main__.Tickerinfo object at 0x00000256E4714E80>, <__main__.Tickerinfo object at 0x00000256E4714E20>, <__main__.Tickerinfo object at 0x00000256E4714FD0>, <__main__.Tickerinfo object at 0x00000256E4714D60>, <__main__.Tickerinfo object at 0x00000256E4715090>, <__main__.Tickerinfo object at 0x00000256E4714C ...
#
# finished scraping

# %%
print(len(tickers))
for t in tickers:
    print(t.name)
# Out:
# 83
# ABNB
# ADBE
# ADI
# ADSK
# AEP
# ALGN
# AMAT
# AMD
# AMGN
# AMZN
# ANSS
# AVGO
# AZN
# BIIB
# BKNG
# BKR
# CEG
# CHTR
# CMCSA
# CPRT
# CRWD
# CSCO
# CSGP
# CSX
# CTAS
# CTSH
# DDOG
# DLTR
# DXCM
# EA
# EBAY
# ENPH
# EXC
# FANG
# FAST
# FTNT
# GFS
# GILD
# HON
# IDXX
# ILMN
# INTU
# JD
# KDP
# KHC
# KLAC
# LRCX
# LULU
# MAR
# MCHP
# MDLZ
# MELI
# MNST
# MRNA
# MRVL
# NVDA
# NXPI
# ODFL
# ON
# ORLY
# PANW
# PAYX
# PCAR
# PEP
# PYPL
# QCOM
# ROST
# SBUX
# SGEN
# SIRI
# SNPS
# TEAM
# TMUS
# TTD
# TXN
# VRSK
# VRTX
# WBA
# WBD
# WDAY
# XEL
# ZM
# ZS
